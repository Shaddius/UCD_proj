# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
walmart_data=pd.read_csv("Walmart_Store_sales.csv")

# %%
walmart_data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
walmart_data.info
# Out:
# <bound method DataFrame.info of       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]>

# %%
walmart_data.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
#Checking missing values for each coloumn
walmart_data.isnull().sum().sort_values(ascending=False)
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
# checking missing values for each row
walmart_data[walmart_data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
droprows= walmart_data.dropna()

# %%
print(walmart_data.shape,droprows.shape)
# Out:
# (6435, 8) (6435, 8)

# %%
walmart_data.info
# Out:
# <bound method DataFrame.info of       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]>

# %%
cleaned_data = walmart_data.fillna(0)

# %%
print (cleaned_data)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
drop_duplicates= walmart_data.drop_duplicates(subset=['Store'])

# %%
print(walmart_data.shape,drop_duplicates.shape)
# Out:
# (6435, 8) (45, 8)

# %%
sorted_walmart_data = walmart_data.sort_values([ 'Date','Weekly_Sales'], ascending=[1,1])

# %%
# To find out the Store with the minimum and maximum sales
sorted_walmart_data
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 4636     33  01-04-2011     232769.09             0        71.41       3.772
# 6209     44  01-04-2011     281514.26             0        42.49       3.487
# 632       5  01-04-2011     314316.55             0        61.50       3.524
# 346       3  01-04-2011     374556.08             0        68.76       3.524
# 5351     38  01-04-2011     382098.13             0        63.63       3.772
# ...     ...         ...           ...           ...          ...         ...
# 1763     13  31-12-2010    1675292.00             1        26.79       2.868
# 1334     10  31-12-2010    1707298.14             1        49.67       3.148
# 190       2  31-12-2010    1750434.55             1        47.30       2.943
# 476       4  31-12-2010    1794868.74             1        38.09       2.955
# 2764     20  31-12-2010    1799737.79             1        28.85       3.179
#
#              CPI  Unemployment
# 4636  128.719935         8.687
# 6209  128.719935         6.906
# 632   215.402441         6.489
# 346   218.211418         7.574
# 5351  128.719935        13.736
# ...          ...           ...
# 1763  127.087677         7.795
# 1334  127.087677         9.003
# 190   211.064774         8.163
# 476   127.087677         7.127
# 2764  204.643227         7.484
#
# [6435 rows x 8 columns]

# %%
sorted_walmart_data.head()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 4636     33  01-04-2011     232769.09             0        71.41       3.772
# 6209     44  01-04-2011     281514.26             0        42.49       3.487
# 632       5  01-04-2011     314316.55             0        61.50       3.524
# 346       3  01-04-2011     374556.08             0        68.76       3.524
# 5351     38  01-04-2011     382098.13             0        63.63       3.772
#
#              CPI  Unemployment
# 4636  128.719935         8.687
# 6209  128.719935         6.906
# 632   215.402441         6.489
# 346   218.211418         7.574
# 5351  128.719935        13.736

# %%
walmart_data.groupby(by=['Weekly_Sales','Date'], as_index=False)['Store'].count().head()
# Out:
#    Weekly_Sales        Date  Store
# 0     209986.25  03-12-2010      1
# 1     213538.32  29-10-2010      1
# 2     215359.21  30-12-2011      1
# 3     219804.85  31-12-2010      1
# 4     220060.35  02-12-2011      1

# %%
walmart_data.groupby(by=['Date','Weekly_Sales'], as_index=False)['Store']. sum()
# Out:
#             Date  Weekly_Sales  Store
# 0     01-04-2011     232769.09     33
# 1     01-04-2011     281514.26     44
# 2     01-04-2011     314316.55      5
# 3     01-04-2011     374556.08      3
# 4     01-04-2011     382098.13     38
# ...          ...           ...    ...
# 6430  31-12-2010    1675292.00     13
# 6431  31-12-2010    1707298.14     10
# 6432  31-12-2010    1750434.55      2
# 6433  31-12-2010    1794868.74      4
# 6434  31-12-2010    1799737.79     20
#
# [6435 rows x 3 columns]

# %%
total_sales= walmart_data.groupby('Store')['Weekly_Sales'].sum().sort_values() 
total_sales_array = np.array(total_sales)
plt.figure(figsize=(10,7))
plt.xticks(rotation=0)
plt.ticklabel_format(useOffset=False, style='plain', axis='y')
plt.title('Total sales for each store')
plt.xlabel('Store')
plt.ylabel('Total Sales')
total_sales.plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'Total sales for each store'}, xlabel='Store', ylabel='Total Sales'>
